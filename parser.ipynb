# %%
import textract
import re

pdf_path = 'data/example_sigma_PL.pdf'
text = textract.process(pdf_path)

# %%
text
# Out:
# b'KARTA CHARAKTERYSTYKI\nzgodnie z Rozporz\xc4\x85dzeniem WE 1907/2006\n\nWersja 8.8\nAktualizacja 27.04.2024\nWydrukowano dnia 12.05.2024\n\nSEKCJA 1: Identyfikacja substancji/mieszaniny i identyfikacja przedsi\xc4\x99biorstwa\n1.1\n\nIdentyfikatory produktu\nNazwa wyrobu\n:\nNumer produktu\nMarka\nNumer indeksowy\nNr REACH\n\nNr CAS\n1.2\n\n1.4\n\n:\n:\n:\n:\n\n54802\nAldrich\n613-285-00-7\nDla tej substancji numer rejestracji nie jest dost\xc4\x99pny, poniewa\xc5\xbc\nsubstancja lub jej zastosowania s\xc4\x85 zwolnione z rejestracji,\nroczna wielko\xc5\x9b\xc4\x87 obrotu nie wymaga rejestracji, lub przewiduje\nsi\xc4\x99 rejestracj\xc4\x99 w p\xc3\xb3\xc5\xbaniejszym terminie rejestracji.\n: 123333-53-9\n\nIstotne zidentyfikowane zastosowania substancji lub mieszaniny oraz\nzastosowania odradzane\nZastosowania\nzidentyfikowane\n\n1.3\n\n1-Hydroksybenzotriazol, hydrat\n\n: Chemikalia laboratoryjne, Produkcja substancji\n\nDane dotycz\xc4\x85ce dostawcy karty charakterystyki\nFirma\
# ...
